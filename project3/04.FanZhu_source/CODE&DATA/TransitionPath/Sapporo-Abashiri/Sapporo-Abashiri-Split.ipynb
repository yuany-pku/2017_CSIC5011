# %%
import pandas as pd
import numpy as np
from discreteMarkovChain import markovChain

# %% [markdown]
# ## Reading Data: Score and Adjancy Matrix

# %%
adj_mat_data = pd.read_csv('JRPASS_split.csv',header=0,index_col=0,nrows=19)
adj_mat = adj_mat_data.values
adj_mat_data
# Out:
#              Sapporo_Sp  Sapporo  Shiretoko  Noboribetsu  Muroran  Otaru  \
# Sapporo_Sp            0        1          0            1        0      1
# Sapporo               1        0          0            1        0      1
# Shiretoko             0        0          0            0        0      0
# Noboribetsu           1        1          0            0        1      1
# Muroran               0        0          0            1        0      1
# Otaru                 1        1          0            1        1      0
# Esashi                0        0          0            0        0      0
# Furano                1        1          0            1        0      0
# Biei                  0        0          0            0        0      0
# Asahikawa             1        1          0            1        0      0
# Kushiro               0        0          1            0        0      0
# Monbetsu              0        0          0            0        0      0
# Numuro                0        0          0            0        0      0
# Wakkanai              0        0          0            0        0      0
# Obihiro               1        1          0            1        0      0
# Rumoi                 1        1          0            0        0      0
# Hakodate              1        1          0            1        1      1
# Abashiri              0        0          1            0        0      0
# Abashiri_Sp           0        0          1            0        0      0
#
#              Esashi  Furano  Biei  Asahikawa  Kushiro  Monbetsu  Numuro  \
# Sapporo_Sp        0       1     0          1        0         0       0
# Sapporo           0       1     0          1        0         0       0
# Shiretoko         0       0     0          0        1         0       0
# Noboribetsu       0       1     0          1        0         0       0
# Muroran           0       0     0          0        0         0       0
# Otaru             0       0     0          0        0         0       0
# Esashi            0       0     0          0        0         0       0
# Furano            0       0     1          0        0         0       0
# Biei              0       1     0          1        0         0       0
# Asahikawa         0       0     1          0        0         1       0
# Kushiro           0       0     0          0        0         0       1
# Monbetsu          0       0     0          1        0         0       0
# Numuro            0       0     0          0        1         0       0
# Wakkanai          0       0     0          1        0         0       0
# Obihiro           0       1     0          0        1         0       0
# Rumoi             0       1     0          1        0         0       0
# Hakodate          1       0     0          0        0         0       0
# Abashiri          0       0     0          1        0         0       0
# Abashiri_Sp       0       0     0          1        0         0       0
#
#              Wakkanai  Obihiro  Rumoi  Hakodate  Abashiri  Abashiri_Sp
# Sapporo_Sp          0        1      1         1         0            0
# Sapporo             0        1      1         1         0            0
# Shiretoko           0        0      0         0         1            1
# Noboribetsu         0        1      0         1         0            0
# Muroran             0        0      0         1         0            0
# Otaru               0        0      0         1         0            0
# Esashi              0        0      0         1         0            0
# Furano              0        1      1         0         0            0
# Biei                0        0      0         0         0            0
# Asahikawa           1        0      1         0         1            1
# Kushiro             0        1      0         0         0            0
# Monbetsu            0        0      0         0         0            0
# Numuro              0        0      0         0         0            0
# Wakkanai            0        0      0         0         0            0
# Obihiro             0        0      0         0         0            0
# Rumoi               0        0      0         0         0            0
# Hakodate            0        0      0         0         0            0
# Abashiri            0        0      0         0         0            1
# Abashiri_Sp         0        0      0         0         1            0

# %%
score_data = pd.read_csv('Score_split.csv',header=0,index_col=0)
score_data
# Out:
#          Sapporo_Sp      Sapporo  Shiretoko  Noboribetsu     Muroran  \
# City
# View_1        500.0   695.000000      692.0       1034.0  202.000000
# Grade_1         NaN     4.500000        4.5          4.0    4.000000
# View_2          0.0  1112.000000      486.0        265.0  114.000000
# Grade_2         NaN     4.500000        4.0          4.5    4.000000
# View_3          0.0  1394.000000      210.0        274.0   36.000000
# Grade_3         NaN     4.000000        4.0          4.0    4.500000
# Score           NaN  4569.166667     1966.0       2141.5  475.333333
#
#                Otaru      Esashi       Furano    Biei  Asahikawa      Kushiro  \
# City
# View_1   2199.000000   54.000000   524.000000   673.0     2179.0   507.000000
# Grade_1     4.000000    4.000000     4.000000     4.5        4.5     4.000000
# View_2    286.000000   30.000000   250.000000  1296.0      201.0   276.000000
# Grade_2     4.000000    4.000000     4.500000     4.0        4.0     4.000000
# View_3    291.000000   38.000000   200.000000   300.0      139.0   176.000000
# Grade_3     4.000000    3.500000     4.000000     4.0        4.5     4.000000
# Score    3701.333333  156.333333  1340.333333  3137.5     3745.0  1278.666667
#
#             Abashiri  Monbetsu  Numuro     Wakkanai      Obihiro       Rumoi  \
# City
# View_1    551.000000      86.0     130   498.000000   366.000000   37.000000
# Grade_1     4.500000       4.0       4     4.000000     4.000000    4.000000
# View_2    263.000000      55.0     137   257.000000   332.000000   19.000000
# Grade_2     4.000000       4.0       4     4.000000     3.500000    4.000000
# View_3    141.000000      63.0      36   247.000000   120.000000   22.000000
# Grade_3     4.000000       4.5       4     3.500000     4.500000    3.500000
# Score    1365.166667     282.5     404  1294.833333  1055.333333  100.333333
#
#          Hakodate  Abashiri_Sp
# City
# View_1     2846.0        300.0
# Grade_1       4.5          NaN
# View_2     1609.0          0.0
# Grade_2       4.0          NaN
# View_3     1238.0          0.0
# Grade_3       4.0          NaN
# Score      8065.0          NaN

# %% [markdown]
# Here we use split strategy to solve passing by the airport problem. Score of Splitting node is a hyper-parameter, which could be tuned according to, for example, the stationary distribution. Here we set two splitting nodes score to be 500 and 100 respectly.

# %%
score = np.max(score_data.values[[0,2,4]],axis=0)
score[-1] = 100
N = score.shape[0]
pd.DataFrame(score.reshape((1,-1)), columns=city, index=['score'])
# Out:
#        Sapporo_Sp  Sapporo  Shiretoko  Noboribetsu  Muroran   Otaru  Esashi  \
# score       500.0   1394.0      692.0       1034.0    202.0  2199.0    54.0
#
#        Furano    Biei  Asahikawa  Kushiro  Monbetsu  Numuro  Wakkanai  \
# score   524.0  1296.0     2179.0    507.0     551.0    86.0     137.0
#
#        Obihiro  Rumoi  Hakodate  Abashiri  Abashiri_Sp
# score    498.0  366.0      37.0    2846.0        100.0

# %%
city = adj_mat_data.columns
print(city)
# Out:
# Index(['Sapporo_Sp', 'Sapporo', 'Shiretoko', 'Noboribetsu', 'Muroran', 'Otaru',
#        'Esashi', 'Furano', 'Biei', 'Asahikawa', 'Kushiro', 'Monbetsu',
#        'Numuro', 'Wakkanai', 'Obihiro', 'Rumoi', 'Hakodate', 'Abashiri',
#        'Abashiri_Sp'],
#       dtype='object')

# %% [markdown]
# ## Transition Matrix

# %%
tran_mat = np.matmul(adj_mat, np.diag(score))
deg = np.sum(tran_mat,axis=1)
tran_mat = np.matmul(np.diag(1/deg), tran_mat)

# %%
df = pd.DataFrame(tran_mat, index=city, columns=city)
df.to_csv('Tran_mat_split.csv')
df
# Out:
#              Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# Sapporo_Sp     0.000000  0.169360   0.000000     0.125623  0.000000  0.267161
# Sapporo        0.068148  0.000000   0.000000     0.140930  0.000000  0.299714
# Shiretoko      0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Noboribetsu    0.066375  0.185052   0.000000     0.000000  0.026815  0.291916
# Muroran        0.000000  0.000000   0.000000     0.316208  0.000000  0.672477
# Otaru          0.157878  0.440164   0.000000     0.326492  0.063783  0.000000
# Esashi         0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Furano         0.098270  0.273978   0.000000     0.203223  0.000000  0.000000
# Biei           0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Asahikawa      0.060798  0.169504   0.000000     0.125730  0.000000  0.000000
# Kushiro        0.000000  0.000000   0.542320     0.000000  0.000000  0.000000
# Monbetsu       0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Numuro         0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Wakkanai       0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Obihiro        0.126295  0.352109   0.000000     0.261177  0.000000  0.000000
# Rumoi          0.108767  0.303241   0.000000     0.000000  0.000000  0.000000
# Hakodate       0.092885  0.258963   0.000000     0.192086  0.037526  0.408508
# Abashiri       0.000000  0.000000   0.232918     0.000000  0.000000  0.000000
# Abashiri_Sp    0.000000  0.000000   0.121043     0.000000  0.000000  0.000000
#
#                Esashi    Furano      Biei  Asahikawa   Kushiro  Monbetsu  \
# Sapporo_Sp   0.000000  0.063662  0.000000   0.264731  0.000000  0.000000
# Sapporo      0.000000  0.071419  0.000000   0.296988  0.000000  0.000000
# Shiretoko    0.000000  0.000000  0.000000   0.000000  0.146829  0.000000
# Noboribetsu  0.000000  0.069561  0.000000   0.289261  0.000000  0.000000
# Muroran      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Otaru        0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Esashi       0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Furano       0.000000  0.000000  0.254717   0.000000  0.000000  0.000000
# Biei         0.000000  0.193859  0.000000   0.806141  0.000000  0.000000
# Asahikawa    0.000000  0.000000  0.157588   0.000000  0.000000  0.066999
# Kushiro      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Monbetsu     0.000000  0.000000  0.000000   1.000000  0.000000  0.000000
# Numuro       0.000000  0.000000  0.000000   0.000000  1.000000  0.000000
# Wakkanai     0.000000  0.000000  0.000000   1.000000  0.000000  0.000000
# Obihiro      0.000000  0.132357  0.000000   0.000000  0.128063  0.000000
# Rumoi        0.000000  0.113987  0.000000   0.474005  0.000000  0.000000
# Hakodate     0.010032  0.000000  0.000000   0.000000  0.000000  0.000000
# Abashiri     0.000000  0.000000  0.000000   0.733423  0.000000  0.000000
# Abashiri_Sp  0.000000  0.000000  0.000000   0.381144  0.000000  0.000000
#
#                Numuro  Wakkanai   Obihiro     Rumoi  Hakodate  Abashiri  \
# Sapporo_Sp   0.000000  0.000000  0.060503  0.044466  0.004495  0.000000
# Sapporo      0.000000  0.000000  0.067875  0.049884  0.005043  0.000000
# Shiretoko    0.000000  0.000000  0.000000  0.000000  0.000000  0.824211
# Noboribetsu  0.000000  0.000000  0.066109  0.000000  0.004912  0.000000
# Muroran      0.000000  0.000000  0.000000  0.000000  0.011315  0.000000
# Otaru        0.000000  0.000000  0.000000  0.000000  0.011683  0.000000
# Esashi       0.000000  0.000000  0.000000  0.000000  1.000000  0.000000
# Furano       0.000000  0.000000  0.097877  0.071934  0.000000  0.000000
# Biei         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Asahikawa    0.000000  0.016659  0.000000  0.044504  0.000000  0.346060
# Kushiro      0.067398  0.000000  0.390282  0.000000  0.000000  0.000000
# Monbetsu     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Numuro       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Wakkanai     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Obihiro      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Rumoi        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Hakodate     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Abashiri     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Abashiri_Sp  0.000000  0.000000  0.000000  0.000000  0.000000  0.497814
#
#              Abashiri_Sp
# Sapporo_Sp      0.000000
# Sapporo         0.000000
# Shiretoko       0.028960
# Noboribetsu     0.000000
# Muroran         0.000000
# Otaru           0.000000
# Esashi          0.000000
# Furano          0.000000
# Biei            0.000000
# Asahikawa       0.012160
# Kushiro         0.000000
# Monbetsu        0.000000
# Numuro          0.000000
# Wakkanai        0.000000
# Obihiro         0.000000
# Rumoi           0.000000
# Hakodate        0.000000
# Abashiri        0.033659
# Abashiri_Sp     0.000000

# %% [markdown]
# ## Stationary Distribution

# %% [markdown]
# Solve a linear equation $\pi * P = \pi$. Here we use package ``discreteMarkovChain``

# %%
mc = markovChain(P=tran_mat)

# %%
mc.computePi('linear')
pd.DataFrame(mc.pi.reshape((1,-1)), columns=city, index=['Prob'])
# Out:
#       Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# Prob    0.057714  0.143431   0.033509     0.109232  0.009263  0.097664
#
#         Esashi    Furano      Biei  Asahikawa   Kushiro  Monbetsu    Numuro  \
# Prob  0.000028  0.037389  0.049126   0.251305  0.009072  0.016837  0.000611
#
#       Wakkanai   Obihiro     Rumoi  Hakodate  Abashiri  Abashiri_Sp
# Prob  0.004186  0.027649  0.023595  0.002793  0.118577     0.008017

# %% [markdown]
# ## Committor function

# %% [markdown]
# Solve a (discrete) Dirichlet boundary problem for committor function, here we should let the boundary be the first col and last col.

# %%
a1 = np.zeros(N)
a1[0] = 1
a2 = np.zeros(N)
a2[-1] = 1
a = np.vstack((tran_mat[1:-1,0], (tran_mat[1:-1,1:-1]-np.identity(N-2)).T, tran_mat[1:-1,-1])).T
a = np.vstack((a1,a,a2))

# %%
b = np.zeros(N)
b[0] = 0
b[-1] = 1

# %%
q = np.linalg.solve(a,b)
pd.DataFrame(q.reshape(1,-1), columns=city, index=['commitor'])
# Out:
#           Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# commitor         0.0  0.107345   0.213638     0.106663  0.094691  0.089155
#
#             Esashi    Furano     Biei  Asahikawa   Kushiro  Monbetsu  \
# commitor  0.089155  0.105625  0.14247   0.151331  0.166482  0.151331
#
#             Numuro  Wakkanai   Obihiro     Rumoi  Hakodate  Abashiri  \
# commitor  0.166482  0.151331  0.100955  0.116323  0.089155  0.194409
#
#           Abashiri_Sp
# commitor          1.0

# %% [markdown]
# ## Effective Flux

# %% [markdown]
# Solve the effective flux on each edge (x,y)
# Firstly, calculate reactive current, which describes the ``reactive flow passing by x and y``.
# Then, effective flux is basically the max(J(xy)-J(yx),0)

# %%
J_dir = np.zeros((N,N))
for x in range(N):
    for y in range(N):
        J_dir[x,y] = mc.pi[x] * (1-q[x]) * tran_mat[x,y] * q[y]

# %%
J_eff = np.maximum(J_dir - J_dir.T, 0)
print(J_eff[0])
np.max(J_eff)
# Out:
# [  0.00000000e+00   1.04923831e-03   0.00000000e+00   7.73328785e-04
#    0.00000000e+00   1.37468166e-03   0.00000000e+00   3.88086444e-04
#    0.00000000e+00   2.31215197e-03   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   3.52524118e-04   2.98522620e-04
#    2.31301598e-05   0.00000000e+00   0.00000000e+00]
# 0.003746322901273632

# %% [markdown]
# ## Transition Current of a Node

# %% [markdown]
# Compute the transition flux through each node x$\in$V.

# %%
flux = np.zeros(N)
flux[0] = np.sum(J_eff[0])
flux[-1] = np.sum(J_eff[:,-1])
for x in np.arange(1,N-1):
    flux[x] = np.sum(J_eff[x,])
    #print(J_eff[x,].sum() - J_eff[:,x].sum())
print(flux)
# Out:
# [  6.57166407e-03   1.93793775e-03   7.63114840e-04   1.42514761e-03
#    3.50659332e-05   1.37468166e-03   0.00000000e+00   4.05175267e-04
#    3.50900291e-04   6.33964848e-03   2.32015582e-04   4.33680869e-19
#    0.00000000e+00   2.16840434e-19   3.52524118e-04   3.91533666e-04
#    2.31301598e-05   3.74632290e-03   6.57166407e-03]

# %%
pd.DataFrame( np.reshape( flux / np.sum(flux[1:-1]), (1,-1)), index=['Current'], columns=city)
# Out:
#          Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# Current    0.378177  0.111522   0.043915     0.082013  0.002018  0.079108
#
#          Esashi    Furano      Biei  Asahikawa   Kushiro      Monbetsu  \
# Current     0.0  0.023316  0.020193   0.364826  0.013352  2.495689e-17
#
#          Numuro      Wakkanai   Obihiro     Rumoi  Hakodate  Abashiri  \
# Current     0.0  1.247845e-17  0.020287  0.022531  0.001331  0.215588
#
#          Abashiri_Sp
# Current     0.378177

# %% [markdown]
# ## Graph Force Layout
