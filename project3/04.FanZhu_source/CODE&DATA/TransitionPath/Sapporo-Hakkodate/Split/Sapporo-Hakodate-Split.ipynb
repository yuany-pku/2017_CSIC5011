# %%
import pandas as pd
import numpy as np
from discreteMarkovChain import markovChain

# %% [markdown]
# ## Reading Data: Score and Adjancy Matrix

# %%
adj_mat_data = pd.read_csv('JRPASS_split.csv',header=0,index_col=0,nrows=19)
adj_mat = adj_mat_data.values
adj_mat_data
# Out:
#              Sapporo_Sp  Sapporo  Shiretoko  Noboribetsu  Muroran  Otaru  \
# Sapporo_Sp            0        1          0            1        0      1
# Sapporo               1        0          0            1        0      1
# Shiretoko             0        0          0            0        0      0
# Noboribetsu           1        1          0            0        1      1
# Muroran               0        0          0            1        0      1
# Otaru                 1        1          0            1        1      0
# Esashi                0        0          0            0        0      0
# Furano                1        1          0            1        0      0
# Biei                  0        0          0            0        0      0
# Asahikawa             1        1          0            1        0      0
# Kushiro               0        0          1            0        0      0
# Abashiri              0        0          1            0        0      0
# Monbetsu              0        0          0            0        0      0
# Numuro                0        0          0            0        0      0
# Wakkanai              0        0          0            0        0      0
# Obihiro               1        1          0            1        0      0
# Rumoi                 1        1          0            0        0      0
# Hakodate              1        1          0            1        1      1
# Hakodate_Sp           0        0          0            1        1      1
#
#              Esashi  Furano  Biei  Asahikawa  Kushiro  Abashiri  Monbetsu  \
# Sapporo_Sp        0       1     0          1        0         0         0
# Sapporo           0       1     0          1        0         0         0
# Shiretoko         0       0     0          0        1         1         0
# Noboribetsu       0       1     0          1        0         0         0
# Muroran           0       0     0          0        0         0         0
# Otaru             0       0     0          0        0         0         0
# Esashi            0       0     0          0        0         0         0
# Furano            0       0     1          0        0         0         0
# Biei              0       1     0          1        0         0         0
# Asahikawa         0       0     1          0        0         1         1
# Kushiro           0       0     0          0        0         0         0
# Abashiri          0       0     0          1        0         0         0
# Monbetsu          0       0     0          1        0         0         0
# Numuro            0       0     0          0        1         0         0
# Wakkanai          0       0     0          1        0         0         0
# Obihiro           0       1     0          0        1         0         0
# Rumoi             0       1     0          1        0         0         0
# Hakodate          1       0     0          0        0         0         0
# Hakodate_Sp       1       0     0          0        0         0         0
#
#              Numuro  Wakkanai  Obihiro  Rumoi  Hakodate  Hakodate_Sp
# Sapporo_Sp        0         0        1      1         1            0
# Sapporo           0         0        1      1         1            0
# Shiretoko         0         0        0      0         0            0
# Noboribetsu       0         0        1      0         1            1
# Muroran           0         0        0      0         1            1
# Otaru             0         0        0      0         1            1
# Esashi            0         0        0      0         1            1
# Furano            0         0        1      1         0            0
# Biei              0         0        0      0         0            0
# Asahikawa         0         1        0      1         0            0
# Kushiro           1         0        1      0         0            0
# Abashiri          0         0        0      0         0            0
# Monbetsu          0         0        0      0         0            0
# Numuro            0         0        0      0         0            0
# Wakkanai          0         0        0      0         0            0
# Obihiro           0         0        0      0         0            0
# Rumoi             0         0        0      0         0            0
# Hakodate          0         0        0      0         0            1
# Hakodate_Sp       0         0        0      0         1            0

# %%
score_data = pd.read_csv('Score_split.csv',header=0,index_col=0)
score_data
# Out:
#          Sapporo_Sp      Sapporo  Shiretoko  Noboribetsu     Muroran  \
# City
# View_1        500.0   695.000000      692.0       1034.0  202.000000
# Grade_1         NaN     4.500000        4.5          4.0    4.000000
# View_2          0.0  1112.000000      486.0        265.0  114.000000
# Grade_2         NaN     4.500000        4.0          4.5    4.000000
# View_3          0.0  1394.000000      210.0        274.0   36.000000
# Grade_3         NaN     4.000000        4.0          4.0    4.500000
# Score           NaN  4569.166667     1966.0       2141.5  475.333333
#
#                Otaru      Esashi       Furano    Biei  Asahikawa      Kushiro  \
# City
# View_1   2199.000000   54.000000   524.000000   673.0     2179.0   507.000000
# Grade_1     4.000000    4.000000     4.000000     4.5        4.5     4.000000
# View_2    286.000000   30.000000   250.000000  1296.0      201.0   276.000000
# Grade_2     4.000000    4.000000     4.500000     4.0        4.0     4.000000
# View_3    291.000000   38.000000   200.000000   300.0      139.0   176.000000
# Grade_3     4.000000    3.500000     4.000000     4.0        4.5     4.000000
# Score    3701.333333  156.333333  1340.333333  3137.5     3745.0  1278.666667
#
#             Abashiri  Monbetsu  Numuro     Wakkanai      Obihiro       Rumoi  \
# City
# View_1    551.000000      86.0     130   498.000000   366.000000   37.000000
# Grade_1     4.500000       4.0       4     4.000000     4.000000    4.000000
# View_2    263.000000      55.0     137   257.000000   332.000000   19.000000
# Grade_2     4.000000       4.0       4     4.000000     3.500000    4.000000
# View_3    141.000000      63.0      36   247.000000   120.000000   22.000000
# Grade_3     4.000000       4.5       4     3.500000     4.500000    3.500000
# Score    1365.166667     282.5     404  1294.833333  1055.333333  100.333333
#
#          Hakodate  Hakodate_Sp
# City
# View_1     2846.0        500.0
# Grade_1       4.5          NaN
# View_2     1609.0          0.0
# Grade_2       4.0          NaN
# View_3     1238.0          0.0
# Grade_3       4.0          NaN
# Score      8065.0          NaN

# %% [markdown]
# Here we use split strategy to solve passing by the airport problem. Score of Splitting node is a hyper-parameter, which could be tuned according to, for example, the stationary distribution. Here we set both of the splitting node score to be 500.

# %%
score = np.max(score_data.values[[0,2,4]],axis=0)
N = score.shape[0]
pd.DataFrame(score.reshape((1,-1)), columns=city, index=['score'])
# Out:
#        Sapporo_Sp  Sapporo  Shiretoko  Noboribetsu  Muroran   Otaru  Esashi  \
# score       500.0   1394.0      692.0       1034.0    202.0  2199.0    54.0
#
#        Furano    Biei  Asahikawa  Kushiro  Abashiri  Monbetsu  Numuro  \
# score   524.0  1296.0     2179.0    507.0     551.0      86.0   137.0
#
#        Wakkanai  Obihiro  Rumoi  Hakodate  Hakodate_Sp
# score     498.0    366.0   37.0    2846.0        500.0

# %%
city = adj_mat_data.columns
print(city)
# Out:
# Index(['Sapporo_Sp', 'Sapporo', 'Shiretoko', 'Noboribetsu', 'Muroran', 'Otaru',
#        'Esashi', 'Furano', 'Biei', 'Asahikawa', 'Kushiro', 'Abashiri',
#        'Monbetsu', 'Numuro', 'Wakkanai', 'Obihiro', 'Rumoi', 'Hakodate',
#        'Hakodate_Sp'],
#       dtype='object')

# %% [markdown]
# ## Transition Matrix

# %%
tran_mat = np.matmul(adj_mat, np.diag(score))
deg = np.sum(tran_mat,axis=1)
tran_mat = np.matmul(np.diag(1/deg), tran_mat)

# %%
df = pd.DataFrame(tran_mat, index=city, columns=city)
df.to_csv('Tran_mat_split.csv')
df
# Out:
#              Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# Sapporo_Sp     0.000000  0.131770   0.000000     0.097741  0.000000  0.207865
# Sapporo        0.051626  0.000000   0.000000     0.106763  0.000000  0.227052
# Shiretoko      0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Noboribetsu    0.046685  0.130159   0.000000     0.000000  0.018861  0.205322
# Muroran        0.000000  0.000000   0.000000     0.157167  0.000000  0.334245
# Otaru          0.077208  0.215256   0.000000     0.159666  0.031192  0.000000
# Esashi         0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Furano         0.108061  0.301275   0.000000     0.223471  0.000000  0.000000
# Biei           0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Asahikawa      0.092661  0.258340   0.000000     0.191623  0.000000  0.000000
# Kushiro        0.000000  0.000000   0.579079     0.000000  0.000000  0.000000
# Abashiri       0.000000  0.000000   0.241031     0.000000  0.000000  0.000000
# Monbetsu       0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Numuro         0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Wakkanai       0.000000  0.000000   0.000000     0.000000  0.000000  0.000000
# Obihiro        0.126295  0.352109   0.000000     0.261177  0.000000  0.000000
# Rumoi          0.108767  0.303241   0.000000     0.000000  0.000000  0.000000
# Hakodate       0.084991  0.236954   0.000000     0.175761  0.034336  0.373789
# Hakodate_Sp    0.000000  0.000000   0.000000     0.163220  0.031886  0.347119
#
#                Esashi    Furano      Biei  Asahikawa   Kushiro  Abashiri  \
# Sapporo_Sp   0.000000  0.049532  0.000000   0.205974  0.000000  0.000000
# Sapporo      0.000000  0.054104  0.000000   0.224987  0.000000  0.000000
# Shiretoko    0.000000  0.000000  0.000000   0.000000  0.479206  0.520794
# Noboribetsu  0.000000  0.048926  0.000000   0.203455  0.000000  0.000000
# Muroran      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Otaru        0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Esashi       0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Furano       0.000000  0.000000  0.280095   0.000000  0.000000  0.000000
# Biei         0.000000  0.193859  0.000000   0.806141  0.000000  0.000000
# Asahikawa    0.000000  0.000000  0.240178   0.000000  0.000000  0.102113
# Kushiro      0.000000  0.000000  0.000000   0.000000  0.000000  0.000000
# Abashiri     0.000000  0.000000  0.000000   0.758969  0.000000  0.000000
# Monbetsu     0.000000  0.000000  0.000000   1.000000  0.000000  0.000000
# Numuro       0.000000  0.000000  0.000000   0.000000  1.000000  0.000000
# Wakkanai     0.000000  0.000000  0.000000   1.000000  0.000000  0.000000
# Obihiro      0.000000  0.132357  0.000000   0.000000  0.128063  0.000000
# Rumoi        0.000000  0.113987  0.000000   0.474005  0.000000  0.000000
# Hakodate     0.009179  0.000000  0.000000   0.000000  0.000000  0.000000
# Hakodate_Sp  0.008524  0.000000  0.000000   0.000000  0.000000  0.000000
#
#              Monbetsu    Numuro  Wakkanai   Obihiro     Rumoi  Hakodate  \
# Sapporo_Sp   0.000000  0.000000  0.000000  0.034597  0.003497  0.269024
# Sapporo      0.000000  0.000000  0.000000  0.037790  0.003820  0.293856
# Shiretoko    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Noboribetsu  0.000000  0.000000  0.000000  0.034174  0.000000  0.265733
# Muroran      0.000000  0.000000  0.000000  0.000000  0.000000  0.432589
# Otaru        0.000000  0.000000  0.000000  0.000000  0.000000  0.439469
# Esashi       0.000000  0.000000  0.000000  0.000000  0.000000  0.850568
# Furano       0.000000  0.000000  0.000000  0.079101  0.007997  0.000000
# Biei         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Asahikawa    0.015938  0.000000  0.092291  0.000000  0.006857  0.000000
# Kushiro      0.000000  0.114644  0.000000  0.306276  0.000000  0.000000
# Abashiri     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Monbetsu     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Numuro       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Wakkanai     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Obihiro      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Rumoi        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Hakodate     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Hakodate_Sp  0.000000  0.000000  0.000000  0.000000  0.000000  0.449250
#
#              Hakodate_Sp
# Sapporo_Sp      0.000000
# Sapporo         0.000000
# Shiretoko       0.000000
# Noboribetsu     0.046685
# Muroran         0.075999
# Otaru           0.077208
# Esashi          0.149432
# Furano          0.000000
# Biei            0.000000
# Asahikawa       0.000000
# Kushiro         0.000000
# Abashiri        0.000000
# Monbetsu        0.000000
# Numuro          0.000000
# Wakkanai        0.000000
# Obihiro         0.000000
# Rumoi           0.000000
# Hakodate        0.084991
# Hakodate_Sp     0.000000

# %% [markdown]
# ## Stationary Distribution

# %% [markdown]
# Solve a linear equation $\pi * P = \pi$. Here we use package ``discreteMarkovChain``

# %%
mc = markovChain(P=tran_mat)

# %%
mc.computePi('linear')
pd.DataFrame(mc.pi.reshape((1,-1)), columns=city, index=['Prob'])
# Out:
#       Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# Prob    0.059371  0.151539   0.008218       0.1243  0.014917  0.159843
#
#         Esashi    Furano     Biei  Asahikawa  Kushiro  Abashiri  Monbetsu  \
# Prob  0.002028  0.027214  0.03932   0.131975   0.0068  0.017756  0.002103
#
#        Numuro  Wakkanai   Obihiro     Rumoi  Hakodate  Hakodate_Sp
# Prob  0.00078   0.01218  0.016264  0.001909   0.18793     0.035553

# %% [markdown]
# ## Committor function

# %% [markdown]
# Solve a (discrete) Dirichlet boundary problem for committor function, here we should let the boundary be the first col and last col.

# %%
a1 = np.zeros(N)
a1[0] = 1
a2 = np.zeros(N)
a2[-1] = 1
a = np.vstack((tran_mat[1:-1,0], (tran_mat[1:-1,1:-1]-np.identity(N-2)).T, tran_mat[1:-1,-1])).T
a = np.vstack((a1,a,a2))

# %%
b = np.zeros(N)
b[0] = 0
b[-1] = 1

# %%
q = np.linalg.solve(a,b)
pd.DataFrame(q.reshape(1,-1), columns=city, index=['commitor'])
# Out:
#           Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# commitor         0.0  0.343657   0.295349      0.37351  0.442575  0.401171
#
#             Esashi   Furano    Biei  Asahikawa   Kushiro  Abashiri  Monbetsu  \
# commitor  0.491129  0.29531  0.2953   0.295298  0.295392   0.29531  0.295298
#
#             Numuro  Wakkanai   Obihiro     Rumoi  Hakodate  Hakodate_Sp
# commitor  0.295392  0.295298  0.295472  0.277845  0.401728          1.0

# %% [markdown]
# ## Effective Flux

# %% [markdown]
# Solve the effective flux on each edge (x,y)
# Firstly, calculate reactive current, which describes the ``reactive flow passing by x and y``.
# Then, effective flux is basically the max(J(xy)-J(yx),0)

# %%
J_dir = np.zeros((N,N))
for x in range(N):
    for y in range(N):
        J_dir[x,y] = mc.pi[x] * (1-q[x]) * tran_mat[x,y] * q[y]

# %%
J_eff = np.maximum(J_dir - J_dir.T, 0)
print(J_eff[0])
np.max(J_eff)
# Out:
# [  0.00000000e+00   2.68856049e-03   0.00000000e+00   2.16747465e-03
#    0.00000000e+00   4.95092655e-03   0.00000000e+00   8.68442143e-04
#    0.00000000e+00   3.61117666e-03   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   6.06916298e-04
#    5.76947213e-05   6.41649978e-03   0.00000000e+00]
# 0.0095557654516622431

# %% [markdown]
# ## Transition Current of a Node

# %% [markdown]
# Compute the transition flux through each node x$\in$V.

# %%
flux = np.zeros(N)
flux[0] = np.sum(J_eff[0])
flux[-1] = np.sum(J_eff[:,-1])
for x in np.arange(1,N-1):
    flux[x] = np.sum(J_eff[x,])
    #print(J_eff[x,].sum() - J_eff[:,x].sum())
print(flux)
# Out:
# [  2.13676913e-02   5.04778551e-03   1.67249977e-07   5.43545569e-03
#    6.31930649e-04   7.63578335e-03   1.54217374e-04   8.72318413e-04
#    7.56198505e-08   3.62697014e-03   1.67249977e-07   1.67249977e-07
#    1.08420217e-19   0.00000000e+00   4.33680869e-19   6.07432180e-04
#    5.76947213e-05   9.97356281e-03   2.13676913e-02]

# %%
pd.DataFrame( np.reshape( flux / np.sum(flux[1:-1]), (1,-1)), index=['Current'], columns=city)
# Out:
#          Sapporo_Sp   Sapporo  Shiretoko  Noboribetsu   Muroran     Otaru  \
# Current    0.627654  0.148274   0.000005     0.159661  0.018562  0.224293
#
#           Esashi    Furano      Biei  Asahikawa   Kushiro  Abashiri  \
# Current  0.00453  0.025623  0.000002   0.106539  0.000005  0.000005
#
#              Monbetsu  Numuro      Wakkanai   Obihiro     Rumoi  Hakodate  \
# Current  3.184734e-18     0.0  1.273894e-17  0.017843  0.001695  0.292963
#
#          Hakodate_Sp
# Current     0.627654

# %% [markdown]
# ## Graph Force Layout

# %%
nodes = []
for index, name in enumerate(city):
    if index == 0 or index == N-1:
        nodes.append({
            'id':name,
            'group':'red',
            'radius':np.mean(flux[1:-1])/2+np.max(flux[1:-1])/2
        })
    else:
        nodes.append({
            'id':name,
            'group':'blue',
            'radius':flux[index]
        })

# %%
nodes
# Out:
# [{'group': 'red', 'id': 'Sapporo_Sp', 'radius': 0.0059880675300605177},
#  {'group': 'blue', 'id': 'Sapporo', 'radius': 0.0050477855057493026},
#  {'group': 'blue', 'id': 'Shiretoko', 'radius': 1.6724997664281996e-07},
#  {'group': 'blue', 'id': 'Noboribetsu', 'radius': 0.0054354556863277295},
#  {'group': 'blue', 'id': 'Muroran', 'radius': 0.00063193064920818943},
#  {'group': 'blue', 'id': 'Otaru', 'radius': 0.0076357833473602345},
#  {'group': 'blue', 'id': 'Esashi', 'radius': 0.00015421737429460879},
#  {'group': 'blue', 'id': 'Furano', 'radius': 0.00087231841310201231},
#  {'group': 'blue', 'id': 'Biei', 'radius': 7.5619850518991033e-08},
#  {'group': 'blue', 'id': 'Asahikawa', 'radius': 0.0036269701389075671},
#  {'group': 'blue', 'id': 'Kushiro', 'radius': 1.6724997664292838e-07},
#  {'group': 'blue', 'id': 'Abashiri', 'radius': 1.672499766424947e-07},
#  {'group': 'blue', 'id': 'Monbetsu', 'radius': 1.0842021724855044e-19},
#  {'group': 'blue', 'id': 'Numuro', 'radius': 0.0},
#  {'group': 'blue', 'id': 'Wakkanai', 'radius': 4.3368086899420177e-19},
#  {'group': 'blue', 'id': 'Obihiro', 'radius': 0.00060743217957757284},
#  {'group': 'blue', 'id': 'Rumoi', 'radius': 5.7694721313042201e-05},
#  {'group': 'blue', 'id': 'Hakodate', 'radius': 0.0099735628131353837},
#  {'group': 'red', 'id': 'Hakodate_Sp', 'radius': 0.0059880675300605177}]

# %%
mean_0 = np.mean(J_eff[0][J_eff[0]!=0])
mean_n = np.mean(J_eff[:,-1][J_eff[:,-1]!=0])
mean = np.percentile(J_eff[1:-1,1:-1][J_eff[1:-1,1:-1]!=0], q=65)
J_eff_copy = J_eff.copy()
J_eff_copy[0] *= mean/mean_0
J_eff_copy[:,-1] *= mean/mean_n

# %%
cut_thresh = np.percentile(J_eff[1:-1,1:-1][J_eff[1:-1,1:-1]!=0],q=75) # stress 1/5

# %%
def f(index1, index2, dis, cut_thresh=cut_thresh):
    if index1 == 0 or index1 == N-1 or index2 == 0 or index2==N-1:
        return 'red'
    elif dis > cut_thresh:
        return 'green'
    else:
        return 'gray'

# %%
links = []
for index1, a in enumerate(adj_mat):
    for index2, b in enumerate(a):
        if index1>index2: 
            if J_dir[index1,index2] > J_dir[index2,index1]:
                links.append({
                    'source':city[index1],
                    'target':city[index2],
                    'value':J_eff_copy[index1,index2],
                    'group': f(index1, index2, J_eff[index1, index2])
                })
            elif J_dir[index2,index1] > J_dir[index1,index2]:
                links.append({
                    'source':city[index2],
                    'target':city[index1],
                    'value':J_eff_copy[index2,index1],
                    'group': f(index1, index2, J_eff[index2, index1])
                })

# %%
graph = {'nodes':nodes,
         'links':links
        }

# %%
import json
with open('Sapporo-Hakodate_TP_Sp.json', 'w') as outfile:
    json.dump(graph, outfile)
