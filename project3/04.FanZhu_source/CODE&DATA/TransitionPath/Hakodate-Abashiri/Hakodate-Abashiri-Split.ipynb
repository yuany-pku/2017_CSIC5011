# %%
import pandas as pd
import numpy as np
from discreteMarkovChain import markovChain

# %% [markdown]
# ## Reading Data: Score and Adjancy Matrix

# %%
adj_mat_data = pd.read_csv('JRPASS_split.csv',header=0,index_col=0,nrows=19)
adj_mat = adj_mat_data.values
adj_mat_data
# Out:
#              Hakodate_Sp  Hakodate  Sapporo  Shiretoko  Noboribetsu  Muroran  \
# Hakodate_Sp            0         1        0          0            1        1
# Hakodate               1         0        1          0            1        1
# Sapporo                0         1        0          0            1        0
# Shiretoko              0         0        0          0            0        0
# Noboribetsu            1         1        1          0            0        1
# Muroran                1         1        0          0            1        0
# Otaru                  1         1        1          0            1        1
# Esashi                 1         1        0          0            0        0
# Furano                 0         0        1          0            1        0
# Biei                   0         0        0          0            0        0
# Asahikawa              0         0        1          0            1        0
# Kushiro                0         0        0          1            0        0
# Monbetsu               0         0        0          0            0        0
# Numuro                 0         0        0          0            0        0
# Wakkanai               0         0        0          0            0        0
# Obihiro                0         0        1          0            1        0
# Rumoi                  0         0        1          0            0        0
# Abashiri               0         0        0          1            0        0
# Abashiri_Sp            0         0        0          1            0        0
#
#              Otaru  Esashi  Furano  Biei  Asahikawa  Kushiro  Monbetsu  \
# Hakodate_Sp      1       1       0     0          0        0         0
# Hakodate         1       1       0     0          0        0         0
# Sapporo          1       0       1     0          1        0         0
# Shiretoko        0       0       0     0          0        1         0
# Noboribetsu      1       0       1     0          1        0         0
# Muroran          1       0       0     0          0        0         0
# Otaru            0       0       0     0          0        0         0
# Esashi           0       0       0     0          0        0         0
# Furano           0       0       0     1          0        0         0
# Biei             0       0       1     0          1        0         0
# Asahikawa        0       0       0     1          0        0         1
# Kushiro          0       0       0     0          0        0         0
# Monbetsu         0       0       0     0          1        0         0
# Numuro           0       0       0     0          0        1         0
# Wakkanai         0       0       0     0          1        0         0
# Obihiro          0       0       1     0          0        1         0
# Rumoi            0       0       1     0          1        0         0
# Abashiri         0       0       0     0          1        0         0
# Abashiri_Sp      0       0       0     0          1        0         0
#
#              Numuro  Wakkanai  Obihiro  Rumoi  Abashiri  Abashiri_Sp
# Hakodate_Sp       0         0        0      0         0            0
# Hakodate          0         0        0      0         0            0
# Sapporo           0         0        1      1         0            0
# Shiretoko         0         0        0      0         1            1
# Noboribetsu       0         0        1      0         0            0
# Muroran           0         0        0      0         0            0
# Otaru             0         0        0      0         0            0
# Esashi            0         0        0      0         0            0
# Furano            0         0        1      1         0            0
# Biei              0         0        0      0         0            0
# Asahikawa         0         1        0      1         1            1
# Kushiro           1         0        1      0         0            0
# Monbetsu          0         0        0      0         0            0
# Numuro            0         0        0      0         0            0
# Wakkanai          0         0        0      0         0            0
# Obihiro           0         0        0      0         0            0
# Rumoi             0         0        0      0         0            0
# Abashiri          0         0        0      0         0            1
# Abashiri_Sp       0         0        0      0         1            0

# %%
score_data = pd.read_csv('Score_split.csv',header=0,index_col=0)
score_data
# Out:
#          Hakodate_Sp  Hakodate      Sapporo  Shiretoko  Noboribetsu  \
# City
# View_1         500.0    2846.0   695.000000      692.0       1034.0
# Grade_1          NaN       4.5     4.500000        4.5          4.0
# View_2           0.0    1609.0  1112.000000      486.0        265.0
# Grade_2          NaN       4.0     4.500000        4.0          4.5
# View_3           0.0    1238.0  1394.000000      210.0        274.0
# Grade_3          NaN       4.0     4.000000        4.0          4.0
# Score            NaN    8065.0  4569.166667     1966.0       2141.5
#
#             Muroran        Otaru      Esashi       Furano    Biei  Asahikawa  \
# City
# View_1   202.000000  2199.000000   54.000000   524.000000   673.0     2179.0
# Grade_1    4.000000     4.000000    4.000000     4.000000     4.5        4.5
# View_2   114.000000   286.000000   30.000000   250.000000  1296.0      201.0
# Grade_2    4.000000     4.000000    4.000000     4.500000     4.0        4.0
# View_3    36.000000   291.000000   38.000000   200.000000   300.0      139.0
# Grade_3    4.500000     4.000000    3.500000     4.000000     4.0        4.5
# Score    475.333333  3701.333333  156.333333  1340.333333  3137.5     3745.0
#
#              Kushiro  Monbetsu  Numuro     Wakkanai      Obihiro       Rumoi  \
# City
# View_1    507.000000      86.0     130   498.000000   366.000000   37.000000
# Grade_1     4.000000       4.0       4     4.000000     4.000000    4.000000
# View_2    276.000000      55.0     137   257.000000   332.000000   19.000000
# Grade_2     4.000000       4.0       4     4.000000     3.500000    4.000000
# View_3    176.000000      63.0      36   247.000000   120.000000   22.000000
# Grade_3     4.000000       4.5       4     3.500000     4.500000    3.500000
# Score    1278.666667     282.5     404  1294.833333  1055.333333  100.333333
#
#             Abashiri  Abashiri_Sp
# City
# View_1    551.000000        100.0
# Grade_1     4.500000          NaN
# View_2    263.000000          0.0
# Grade_2     4.000000          NaN
# View_3    141.000000          0.0
# Grade_3     4.000000          NaN
# Score    1365.166667          NaN

# %% [markdown]
# Here we use split strategy to solve passing by the airport problem. Score of Splitting node is a hyper-parameter, which could be tuned according to, for example, the stationary distribution. Here we set both of the splitting node score to be 500.

# %%
score = np.max(score_data.values[[0,2,4]],axis=0)
N = score.shape[0]
pd.DataFrame(score.reshape((1,-1)), columns=city, index=['score'])
# Out:
#        Hakodate_Sp  Hakodate  Sapporo  Shiretoko  Noboribetsu  Muroran  \
# score        500.0    2846.0   1394.0      692.0       1034.0    202.0
#
#         Otaru  Esashi  Furano    Biei  Asahikawa  Kushiro  Monbetsu  Numuro  \
# score  2199.0    54.0   524.0  1296.0     2179.0    507.0      86.0   137.0
#
#        Wakkanai  Obihiro  Rumoi  Abashiri  Abashiri_Sp
# score     498.0    366.0   37.0     551.0        100.0

# %%
city = adj_mat_data.columns
print(city)
# Out:
# Index(['Hakodate_Sp', 'Hakodate', 'Sapporo', 'Shiretoko', 'Noboribetsu',
#        'Muroran', 'Otaru', 'Esashi', 'Furano', 'Biei', 'Asahikawa', 'Kushiro',
#        'Monbetsu', 'Numuro', 'Wakkanai', 'Obihiro', 'Rumoi', 'Abashiri',
#        'Abashiri_Sp'],
#       dtype='object')

# %% [markdown]
# ## Transition Matrix

# %%
tran_mat = np.matmul(adj_mat, np.diag(score))
deg = np.sum(tran_mat,axis=1)
tran_mat = np.matmul(np.diag(1/deg), tran_mat)

# %%
df = pd.DataFrame(tran_mat, index=city, columns=city)
df.to_csv('Tran_mat_split.csv')
df
# Out:
#              Hakodate_Sp  Hakodate   Sapporo  Shiretoko  Noboribetsu  \
# Hakodate_Sp     0.000000  0.449250  0.000000   0.000000     0.163220
# Hakodate        0.092885  0.000000  0.258963   0.000000     0.192086
# Sapporo         0.000000  0.309853  0.000000   0.000000     0.112575
# Shiretoko       0.000000  0.000000  0.000000   0.000000     0.000000
# Noboribetsu     0.048972  0.278746  0.136533   0.000000     0.000000
# Muroran         0.075999  0.432589  0.000000   0.000000     0.157167
# Otaru           0.083668  0.476238  0.233266   0.000000     0.173025
# Esashi          0.149432  0.850568  0.000000   0.000000     0.000000
# Furano          0.000000  0.000000  0.337776   0.000000     0.250545
# Biei            0.000000  0.000000  0.000000   0.000000     0.000000
# Asahikawa       0.000000  0.000000  0.279023   0.000000     0.206966
# Kushiro         0.000000  0.000000  0.000000   0.579079     0.000000
# Monbetsu        0.000000  0.000000  0.000000   0.000000     0.000000
# Numuro          0.000000  0.000000  0.000000   0.000000     0.000000
# Wakkanai        0.000000  0.000000  0.000000   0.000000     0.000000
# Obihiro         0.000000  0.000000  0.403007   0.000000     0.298930
# Rumoi           0.000000  0.000000  0.340249   0.000000     0.000000
# Abashiri        0.000000  0.000000  0.000000   0.232918     0.000000
# Abashiri_Sp     0.000000  0.000000  0.000000   0.202221     0.000000
#
#               Muroran     Otaru    Esashi    Furano      Biei  Asahikawa  \
# Hakodate_Sp  0.031886  0.347119  0.008524  0.000000  0.000000   0.000000
# Hakodate     0.037526  0.408508  0.010032  0.000000  0.000000   0.000000
# Sapporo      0.000000  0.239412  0.000000  0.057050  0.000000   0.237235
# Shiretoko    0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# Noboribetsu  0.019785  0.215377  0.000000  0.051322  0.000000   0.213418
# Muroran      0.000000  0.334245  0.000000  0.000000  0.000000   0.000000
# Otaru        0.033802  0.000000  0.000000  0.000000  0.000000   0.000000
# Esashi       0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# Furano       0.000000  0.000000  0.000000  0.000000  0.314030   0.000000
# Biei         0.000000  0.000000  0.000000  0.193859  0.000000   0.806141
# Asahikawa    0.000000  0.000000  0.000000  0.000000  0.259408   0.000000
# Kushiro      0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# Monbetsu     0.000000  0.000000  0.000000  0.000000  0.000000   1.000000
# Numuro       0.000000  0.000000  0.000000  0.000000  0.000000   0.000000
# Wakkanai     0.000000  0.000000  0.000000  0.000000  0.000000   1.000000
# Obihiro      0.000000  0.000000  0.000000  0.151489  0.000000   0.000000
# Rumoi        0.000000  0.000000  0.000000  0.127898  0.000000   0.531853
# Abashiri     0.000000  0.000000  0.000000  0.000000  0.000000   0.733423
# Abashiri_Sp  0.000000  0.000000  0.000000  0.000000  0.000000   0.636762
#
#               Kushiro  Monbetsu    Numuro  Wakkanai   Obihiro     Rumoi  \
# Hakodate_Sp  0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Hakodate     0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Sapporo      0.000000  0.000000  0.000000   0.00000  0.039848  0.004028
# Shiretoko    0.437824  0.000000  0.000000   0.00000  0.000000  0.000000
# Noboribetsu  0.000000  0.000000  0.000000   0.00000  0.035847  0.000000
# Muroran      0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Otaru        0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Esashi       0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Furano       0.000000  0.000000  0.000000   0.00000  0.088684  0.008965
# Biei         0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Asahikawa    0.000000  0.017214  0.000000   0.09968  0.000000  0.007406
# Kushiro      0.000000  0.000000  0.114644   0.00000  0.306276  0.000000
# Monbetsu     0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Numuro       1.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Wakkanai     0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Obihiro      0.146574  0.000000  0.000000   0.00000  0.000000  0.000000
# Rumoi        0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Abashiri     0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
# Abashiri_Sp  0.000000  0.000000  0.000000   0.00000  0.000000  0.000000
#
#              Abashiri  Abashiri_Sp
# Hakodate_Sp  0.000000     0.000000
# Hakodate     0.000000     0.000000
# Sapporo      0.000000     0.000000
# Shiretoko    0.475820     0.086356
# Noboribetsu  0.000000     0.000000
# Muroran      0.000000     0.000000
# Otaru        0.000000     0.000000
# Esashi       0.000000     0.000000
# Furano       0.000000     0.000000
# Biei         0.000000     0.000000
# Asahikawa    0.110288     0.020016
# Kushiro      0.000000     0.000000
# Monbetsu     0.000000     0.000000
# Numuro       0.000000     0.000000
# Wakkanai     0.000000     0.000000
# Obihiro      0.000000     0.000000
# Rumoi        0.000000     0.000000
# Abashiri     0.000000     0.033659
# Abashiri_Sp  0.161017     0.000000

# %% [markdown]
# ## Stationary Distribution

# %% [markdown]
# Solve a linear equation $\pi * P = \pi$. Here we use package ``discreteMarkovChain``

# %%
mc = markovChain(P=tran_mat)

# %%
mc.computePi('linear')
pd.DataFrame(mc.pi.reshape((1,-1)), columns=city, index=['Prob'])
# Out:
#       Hakodate_Sp  Hakodate   Sapporo  Shiretoko  Noboribetsu  Muroran  \
# Prob     0.039995  0.193441  0.161671   0.010118     0.133302  0.01678
#
#         Otaru    Esashi    Furano      Biei  Asahikawa  Kushiro  Monbetsu  \
# Prob  0.16593  0.002281  0.027306  0.044232   0.137458  0.00765  0.002366
#
#         Numuro  Wakkanai   Obihiro     Rumoi  Abashiri  Abashiri_Sp
# Prob  0.000877  0.013702  0.015985  0.001914   0.02067     0.004321

# %% [markdown]
# ## Committor function

# %% [markdown]
# Solve a (discrete) Dirichlet boundary problem for committor function, here we should let the boundary be the first col and last col.

# %%
a1 = np.zeros(N)
a1[0] = 1
a2 = np.zeros(N)
a2[-1] = 1
a = np.vstack((tran_mat[1:-1,0], (tran_mat[1:-1,1:-1]-np.identity(N-2)).T, tran_mat[1:-1,-1])).T
a = np.vstack((a1,a,a2))

# %%
b = np.zeros(N)
b[0] = 0
b[-1] = 1

# %%
q = np.linalg.solve(a,b)
pd.DataFrame(q.reshape(1,-1), columns=city, index=['commitor'])
# Out:
#           Hakodate_Sp  Hakodate   Sapporo  Shiretoko  Noboribetsu   Muroran  \
# commitor          0.0  0.085578  0.105978   0.287463     0.100745  0.081486
#
#              Otaru   Esashi    Furano      Biei  Asahikawa   Kushiro  \
# commitor  0.085662  0.07279  0.118205  0.143129   0.149122  0.231126
#
#           Monbetsu    Numuro  Wakkanai   Obihiro     Rumoi  Abashiri  \
# commitor  0.149122  0.231126  0.149122  0.124609  0.130488  0.209984
#
#           Abashiri_Sp
# commitor          1.0

# %% [markdown]
# ## Effective Flux

# %% [markdown]
# Solve the effective flux on each edge (x,y)
# Firstly, calculate reactive current, which describes the ``reactive flow passing by x and y``.
# Then, effective flux is basically the max(J(xy)-J(yx),0)

# %%
J_dir = np.zeros((N,N))
for x in range(N):
    for y in range(N):
        J_dir[x,y] = mc.pi[x] * (1-q[x]) * tran_mat[x,y] * q[y]

# %%
J_eff = np.maximum(J_dir - J_dir.T, 0)
print(J_eff[0])
np.max(J_eff)
# Out:
# [  0.00000000e+00   1.53764538e-03   0.00000000e+00   0.00000000e+00
#    6.57661761e-04   1.03918765e-04   1.18925501e-03   2.48155560e-05
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00]
# 0.0023410667858769444

# %% [markdown]
# ## Transition Current of a Node

# %% [markdown]
# Compute the transition flux through each node x$\in$V.

# %%
flux = np.zeros(N)
flux[0] = np.sum(J_eff[0])
flux[-1] = np.sum(J_eff[:,-1])
for x in np.arange(1,N-1):
    flux[x] = np.sum(J_eff[x,])
    #print(J_eff[x,].sum() - J_eff[:,x].sum())
print(flux)
# Out:
# [  3.51329647e-03   1.59216406e-03   1.90351274e-03   6.22591313e-04
#    1.70503026e-03   1.03918765e-04   1.21935447e-03   2.48155560e-05
#    2.32229102e-04   2.13714097e-04   3.26372458e-03   2.49571890e-04
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   2.49571890e-04
#    1.89694384e-05   9.22657798e-04   3.51329647e-03]

# %%
pd.DataFrame( np.reshape( flux / np.sum(flux[1:-1]), (1,-1)), index=['Current'], columns=city)
# Out:
#          Hakodate_Sp  Hakodate   Sapporo  Shiretoko  Noboribetsu   Muroran  \
# Current     0.285128  0.129215  0.154483   0.050528     0.138375  0.008434
#
#             Otaru    Esashi    Furano      Biei  Asahikawa   Kushiro  \
# Current  0.098959  0.002014  0.018847  0.017344   0.264873  0.020254
#
#          Monbetsu  Numuro  Wakkanai   Obihiro     Rumoi  Abashiri  Abashiri_Sp
# Current       0.0     0.0       0.0  0.020254  0.001539   0.07488     0.285128

# %% [markdown]
# ## Graph Force Layout

# %%
nodes = []
for index, name in enumerate(city):
    if index == 0 or index == N-1:
        nodes.append({
            'id':name,
            'group':'red',
            'radius':np.mean(flux[1:-1])/2+np.max(flux[1:-1])/2
        })
    else:
        nodes.append({
            'id':name,
            'group':'blue',
            'radius':flux[index]
        })

# %%
nodes
# Out:
# [{'group': 'red', 'id': 'Hakodate_Sp', 'radius': 0.0019942689375321652},
#  {'group': 'blue', 'id': 'Hakodate', 'radius': 0.0015921640579169959},
#  {'group': 'blue', 'id': 'Sapporo', 'radius': 0.0019035127385478626},
#  {'group': 'blue', 'id': 'Shiretoko', 'radius': 0.00062259131265915511},
#  {'group': 'blue', 'id': 'Noboribetsu', 'radius': 0.0017050302591372231},
#  {'group': 'blue', 'id': 'Muroran', 'radius': 0.00010391876498277227},
#  {'group': 'blue', 'id': 'Otaru', 'radius': 0.0012193544667451015},
#  {'group': 'blue', 'id': 'Esashi', 'radius': 2.4815556027535401e-05},
#  {'group': 'blue', 'id': 'Furano', 'radius': 0.00023222910220113178},
#  {'group': 'blue', 'id': 'Biei', 'radius': 0.00021371409745312309},
#  {'group': 'blue', 'id': 'Asahikawa', 'radius': 0.0032637245835738901},
#  {'group': 'blue', 'id': 'Kushiro', 'radius': 0.00024957189001888788},
#  {'group': 'blue', 'id': 'Monbetsu', 'radius': 0.0},
#  {'group': 'blue', 'id': 'Numuro', 'radius': 0.0},
#  {'group': 'blue', 'id': 'Wakkanai', 'radius': 0.0},
#  {'group': 'blue', 'id': 'Obihiro', 'radius': 0.00024957189001888831},
#  {'group': 'blue', 'id': 'Rumoi', 'radius': 1.8969438357965745e-05},
#  {'group': 'blue', 'id': 'Abashiri', 'radius': 0.0009226577976969454},
#  {'group': 'red', 'id': 'Abashiri_Sp', 'radius': 0.0019942689375321652}]

# %%
mean_0 = np.mean(J_eff[0][J_eff[0]!=0])
mean_n = np.mean(J_eff[:,-1][J_eff[:,-1]!=0])
mean = np.percentile(J_eff[1:-1,1:-1][J_eff[1:-1,1:-1]!=0], q=65)
J_eff_copy = J_eff.copy()
J_eff_copy[0] *= mean/mean_0
J_eff_copy[:,-1] *= mean/mean_n

# %%
cut_thresh = np.percentile(J_eff[1:-1,1:-1][J_eff[1:-1,1:-1]!=0],q=75) # stress 1/5

# %%
def f(index1, index2, dis, cut_thresh=cut_thresh):
    if index1 == 0 or index1 == N-1 or index2 == 0 or index2==N-1:
        return 'red'
    elif dis > cut_thresh:
        return 'green'
    else:
        return 'gray'

# %%
links = []
for index1, a in enumerate(adj_mat):
    for index2, b in enumerate(a):
        if index1>index2: 
            if J_dir[index1,index2] > J_dir[index2,index1]:
                links.append({
                    'source':city[index1],
                    'target':city[index2],
                    'value':J_eff_copy[index1,index2],
                    'group': f(index1, index2, J_eff[index1, index2])
                })
            elif J_dir[index2,index1] > J_dir[index1,index2]:
                links.append({
                    'source':city[index2],
                    'target':city[index1],
                    'value':J_eff_copy[index2,index1],
                    'group': f(index1, index2, J_eff[index2, index1])
                })

# %%
graph = {'nodes':nodes,
         'links':links
        }

# %%
import json
with open('Hakodate-Abashiri_TP_Sp.json', 'w') as outfile:
    json.dump(graph, outfile)
